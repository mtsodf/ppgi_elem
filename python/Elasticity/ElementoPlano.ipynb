# %%
from sympy import *
import math
from matplotlib.mlab import griddata
from mpl_toolkits.mplot3d import Axes3D
import pylab as plt
from matplotlib import cm
import numpy as np

# %%
init_printing(use_latex="mathjax")

# %%
expr
# Out:
# <module 'sympy.core.expr' from '/home/bho6/softwares/anaconda2/lib/python2.7/site-packages/sympy/core/expr.pyc'>

# %%
def convert_to_np(A):
    Anp = np.zeros(A.shape)
    
    for i in xrange(A.shape[0]):
        for j in xrange(A.shape[1]):
            Anp[i,j] = A[i,j]
    return Anp

# %%
E_value = 1
v_value = 0.25
dx_value = 0.1
dy_value = 0.1

# %% [markdown]
# ## Symbols

# %%
x, y = symbols("x y")

# %%
dx, dy= symbols("dx dy")

# %% [markdown]
# ## Funções de Forma

# %%
N1 = (1-x/dx)*(1-y/dy)
N2 = (1-x/dx)*(0+y/dy)
N3 = (0+x/dx)*(0+y/dy)
N4 = (0+x/dx)*(1-y/dy)

# %%
for N in [N1, N2, N3, N4]:

    X = np.linspace(0, dx_value)
    Y = np.linspace(0, dy_value)
    n = len(X)
    Z = np.zeros(n*n)


    
    i = 0
    for xx in X:
        for yy in Y:
            Z[i] = N.doit().subs(x, xx).subs(y, yy).subs(dx, dx_value).subs(dy, dy_value)
            i += 1

    X, Y = np.meshgrid(X, Y)

    Z = np.reshape(Z, (n, n))


    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

    plt.show()

# %% [markdown]
# ## Matriz de Elasticidade

# %%
E, v = symbols("E v")
Dinv = (1/E)*Matrix([[1,-v,0], [-v,1,0], [0, 0,2*(1+v)]])
D = simplify(Dinv**-1)

# %%
D
# Out:
# ⎡ -E     -E⋅v             ⎤
# ⎢──────  ──────      0    ⎥
# ⎢ 2       2               ⎥
# ⎢v  - 1  v  - 1           ⎥
# ⎢                         ⎥
# ⎢-E⋅v     -E              ⎥
# ⎢──────  ──────      0    ⎥
# ⎢ 2       2               ⎥
# ⎢v  - 1  v  - 1           ⎥
# ⎢                         ⎥
# ⎢                    E    ⎥
# ⎢  0       0     ─────────⎥
# ⎣                2⋅(v + 1)⎦

# %%
A = Matrix([[1,2],[3,4],[5,6]])
A.shape
# Out:
# (3, 2)

# %%
def applyS(N):

    ddx = diff(N, x)
    ddy = diff(N, y)
    
    return Matrix([[ddx, 0], [0, ddy],  [ddy, ddx]])

# %%
applyS(N1)
# Out:
# ⎡ ⎛    y ⎞             ⎤
# ⎢-⎜1 - ──⎟             ⎥
# ⎢ ⎝    dy⎠             ⎥
# ⎢──────────      0     ⎥
# ⎢    dx                ⎥
# ⎢                      ⎥
# ⎢             ⎛    x ⎞ ⎥
# ⎢            -⎜1 - ──⎟ ⎥
# ⎢             ⎝    dx⎠ ⎥
# ⎢    0       ──────────⎥
# ⎢                dy    ⎥
# ⎢                      ⎥
# ⎢ ⎛    x ⎞    ⎛    y ⎞ ⎥
# ⎢-⎜1 - ──⎟   -⎜1 - ──⎟ ⎥
# ⎢ ⎝    dx⎠    ⎝    dy⎠ ⎥
# ⎢──────────  ──────────⎥
# ⎣    dy          dx    ⎦

# %%
Stiff = applyS(N1).T*D*applyS(N2)
Aux = zeros(2,2)
for i in range(Stiff.shape[0]*Stiff.shape[1]):
    Aux[i] = Integral(Stiff[i],(x, 0, dx))
    Aux[i] = Integral(Aux[i],(y, 0, dy))
Stiff = Aux
Stiff
# Out:
# ⎡   dy dx
# ⎢   ⌠  ⌠                                                dy dx
# ⎢   ⎮  ⎮  ⎛             2                   ⎞           ⌠  ⌠
# ⎢   ⎮  ⎮  ⎜     ⎛    x ⎞           ⎛    y ⎞ ⎟           ⎮  ⎮  ⎛    ⎛    x ⎞ ⎛
# ⎢   ⎮  ⎮  ⎜   E⋅⎜1 - ──⎟       E⋅y⋅⎜1 - ──⎟ ⎟           ⎮  ⎮  ⎜E⋅v⋅⎜1 - ──⎟⋅⎜1
# ⎢   ⎮  ⎮  ⎜     ⎝    dx⎠           ⎝    dy⎠ ⎟           ⎮  ⎮  ⎜    ⎝    dx⎠ ⎝
# ⎢   ⎮  ⎮  ⎜- ───────────── - ───────────────⎟ dx dy     ⎮  ⎮  ⎜───────────────
# ⎢   ⎮  ⎮  ⎜      2             2    ⎛ 2    ⎞⎟           ⎮  ⎮  ⎜          ⎛ 2
# ⎢   ⎮  ⎮  ⎝  2⋅dy ⋅(v + 1)   dx ⋅dy⋅⎝v  - 1⎠⎠           ⎮  ⎮  ⎝    dx⋅dy⋅⎝v  -
# ⎢   ⌡  ⌡                                                ⌡  ⌡
# ⎢   0  0                                                0  0
# ⎢
# ⎢                                                           dy dx
# ⎢dy dx                                                      ⌠  ⌠
# ⎢⌠  ⌠                                                       ⎮  ⎮  ⎛          2
# ⎢⎮  ⎮  ⎛    ⎛    x ⎞ ⎛    y ⎞          ⎛    x ⎞⎞            ⎮  ⎮  ⎜  ⎛    x ⎞
# ⎢⎮  ⎮  ⎜  E⋅⎜1 - ──⎟⋅⎜1 - ──⎟    E⋅v⋅y⋅⎜1 - ──⎟⎟            ⎮  ⎮  ⎜E⋅⎜1 - ──⎟
# ⎢⎮  ⎮  ⎜    ⎝    dx⎠ ⎝    dy⎠          ⎝    dx⎠⎟            ⎮  ⎮  ⎜  ⎝    dx⎠
# ⎢⎮  ⎮  ⎜- ─────────────────── - ───────────────⎟ dx dy      ⎮  ⎮  ⎜───────────
# ⎢⎮  ⎮  ⎜    2⋅dx⋅dy⋅(v + 1)          2 ⎛ 2    ⎞⎟            ⎮  ⎮  ⎜  2 ⎛ 2
# ⎢⎮  ⎮  ⎝                        dx⋅dy ⋅⎝v  - 1⎠⎠            ⎮  ⎮  ⎝dy ⋅⎝v  - 1
# ⎢⌡  ⌡                                                       ⌡  ⌡
# ⎣0  0                                                       0  0
#
#                                 ⎤
#                                 ⎥
#                                 ⎥
#    y ⎞         ⎛    x ⎞  ⎞      ⎥
#  - ──⎟     E⋅y⋅⎜1 - ──⎟  ⎟      ⎥
#    dy⎠         ⎝    dx⎠  ⎟      ⎥
# ────── + ────────────────⎟ dx dy⎥
#   ⎞             2        ⎟      ⎥
#  1⎠      2⋅dx⋅dy ⋅(v + 1)⎠      ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
#                     ⎞           ⎥
#           ⎛    y ⎞  ⎟           ⎥
#       E⋅y⋅⎜1 - ──⎟  ⎟           ⎥
#           ⎝    dy⎠  ⎟           ⎥
# ─ + ────────────────⎟ dx dy     ⎥
# ⎞       2           ⎟           ⎥
# ⎠   2⋅dx ⋅dy⋅(v + 1)⎠           ⎥
#                                 ⎥
#                                 ⎦

# %% [raw]
# Stiff = applyS(N1).T*D*applyS(N2)
# Stiff = Integral(Stiff,(x, 0, dx))
# Stiff = Integral(Stiff,(y, 0, dy))
# Stiff = Integral(Stiff,(z, 0, dz))
# Stiff

# %%
def CalcConnectionAnalitic(N1, N2):
    Stiff = applyS(N1).T*D*applyS(N2)
    
    Aux = zeros(Stiff.shape[0], Stiff.shape[1])
    
    for i in range(Stiff.shape[0]*Stiff.shape[1]):
        Aux[i] = Integral(Stiff[i],(x, 0, dx))
        Aux[i] = Integral(Aux[i],(y, 0, dy))
        Aux[i] = simplify(Aux[i])

    Stiff = Aux
   
    return Stiff

# %%
evaluate(CalcConnectionAnalitic(N1, N1))

# %%
def CalcConnection(N1, N2):
    Stiff = applyS(N1).T*D*applyS(N2)
    
    Aux = zeros(Stiff.shape[0], Stiff.shape[1])
    
    for i in range(Stiff.shape[0]*Stiff.shape[1]):
        Aux[i] = Integral(Stiff[i],(x, 0, dx))
        Aux[i] = Integral(Aux[i],(y, 0, dy))
        Aux[i] = Integral(Aux[i],(z, 0, dz))
    
    Stiff = Aux
   
    for i in range(Stiff.shape[0]*Stiff.shape[1]):
        Aux[i]=Stiff[i].doit().subs(E, E_value).subs(v, v_value).subs(dx, dx_value).subs(dy, dy_value).subs(dz, dz_value)

    Stiff = Aux
    return Stiff

# %%
def evaluate(M):
    return M.doit().subs(E, E_value).subs(v, v_value).subs(dx, dx_value).subs(dy, dy_value)

# %%
Ns = [N1, N2, N3, N4]

def build_line(i):
    M = CalcConnectionAnalitic(Ns[i], Ns[0])
    
    for j in range(1, 4):
        M = M.col_insert(2*j, CalcConnectionAnalitic(Ns[i], Ns[j]))
        
    return M

M = build_line(0)

for i in range(1, 4):
    M = M.row_insert(2*i, build_line(i))
M
# Out:
# ⎡  dy dx
# ⎢  ⌠  ⌠                                                                dy dx
# ⎢  ⎮  ⎮    ⎛        2 ⎛ 2    ⎞             2        ⎞                  ⌠  ⌠
# ⎢  ⎮  ⎮  E⋅⎝(dx - x) ⋅⎝v  - 1⎠ - 2⋅(dy - y) ⋅(v + 1)⎠                  ⎮  ⎮  -
# ⎢  ⎮  ⎮  ──────────────────────────────────────────── dx dy            ⎮  ⎮  ─
# ⎢  ⎮  ⎮               2   2         ⎛ 2    ⎞                           ⎮  ⎮
# ⎢  ⎮  ⎮           2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                           ⎮  ⎮
# ⎢  ⌡  ⌡                                                                ⌡  ⌡
# ⎢  0  0                                                                0  0
# ⎢
# ⎢                                                               dy dx
# ⎢        dy dx                                                  ⌠  ⌠
# ⎢        ⌠  ⌠                                                   ⎮  ⎮    ⎛
# ⎢        ⎮  ⎮  -E⋅(dx⋅dy - dx⋅y - dy⋅x + x⋅y)                   ⎮  ⎮  E⋅⎝- 2⋅(
# ⎢        ⎮  ⎮  ─────────────────────────────── dx dy            ⎮  ⎮  ────────
# ⎢        ⎮  ⎮             2   2                                 ⎮  ⎮
# ⎢        ⎮  ⎮         2⋅dx ⋅dy ⋅(v - 1)                         ⎮  ⎮
# ⎢        ⌡  ⌡                                                   ⌡  ⌡
# ⎢        0  0                                                   0  0
# ⎢
# ⎢dy dx                                                         dy dx
# ⎢⌠  ⌠                                                          ⌠  ⌠
# ⎢⎮  ⎮    ⎛                                2 ⎛   2    ⎞⎞        ⎮  ⎮
# ⎢⎮  ⎮  E⋅⎝-2⋅y⋅(dy - y)⋅(v + 1) + (dx - x) ⋅⎝- v  + 1⎠⎠        ⎮  ⎮  -E⋅(dx -
# ⎢⎮  ⎮  ──────────────────────────────────────────────── dx dy  ⎮  ⎮  ─────────
# ⎢⎮  ⎮                 2   2         ⎛ 2    ⎞                   ⎮  ⎮
# ⎢⎮  ⎮             2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                   ⎮  ⎮
# ⎢⌡  ⌡                                                          ⌡  ⌡
# ⎢0  0                                                          0  0
# ⎢
# ⎢ dy dx                                                         dy dx
# ⎢ ⌠  ⌠                                                          ⌠  ⌠
# ⎢ ⎮  ⎮             ⎛                         ⎛ 2    ⎞⎞          ⎮  ⎮    ⎛
# ⎢ ⎮  ⎮  E⋅(dx - x)⋅⎝2⋅v⋅(dy - y)⋅(v + 1) + y⋅⎝v  - 1⎠⎠          ⎮  ⎮  E⋅⎝y⋅(dy
# ⎢ ⎮  ⎮  ────────────────────────────────────────────── dx dy    ⎮  ⎮  ────────
# ⎢ ⎮  ⎮                2   2         ⎛ 2    ⎞                    ⎮  ⎮
# ⎢ ⎮  ⎮            2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                    ⎮  ⎮
# ⎢ ⌡  ⌡                                                          ⌡  ⌡
# ⎢ 0  0                                                          0  0
# ⎢
# ⎢dy dx                                                         dy dx
# ⎢⌠  ⌠                                                          ⌠  ⌠
# ⎢⎮  ⎮    ⎛             ⎛ 2    ⎞                       ⎞        ⎮  ⎮    ⎛
# ⎢⎮  ⎮  E⋅⎝- x⋅(dx - x)⋅⎝v  - 1⎠ + 2⋅y⋅(dy - y)⋅(v + 1)⎠        ⎮  ⎮  E⋅⎝2⋅v⋅y⋅
# ⎢⎮  ⎮  ──────────────────────────────────────────────── dx dy  ⎮  ⎮  ─────────
# ⎢⎮  ⎮                 2   2         ⎛ 2    ⎞                   ⎮  ⎮
# ⎢⎮  ⎮             2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                   ⎮  ⎮
# ⎢⌡  ⌡                                                          ⌡  ⌡
# ⎢0  0                                                          0  0
# ⎢
# ⎢dy dx                                                          dy dx
# ⎢⌠  ⌠                                                           ⌠  ⌠
# ⎢⎮  ⎮    ⎛                                    ⎛ 2    ⎞⎞         ⎮  ⎮    ⎛
# ⎢⎮  ⎮  E⋅⎝2⋅v⋅x⋅(dy - y)⋅(v + 1) - y⋅(dx - x)⋅⎝v  - 1⎠⎠         ⎮  ⎮  E⋅⎝2⋅x⋅(
# ⎢⎮  ⎮  ──────────────────────────────────────────────── dx dy   ⎮  ⎮  ────────
# ⎢⎮  ⎮                 2   2         ⎛ 2    ⎞                    ⎮  ⎮
# ⎢⎮  ⎮             2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                    ⎮  ⎮
# ⎢⌡  ⌡                                                           ⌡  ⌡
# ⎢0  0                                                           0  0
# ⎢
# ⎢ dy dx                                                         dy dx
# ⎢ ⌠  ⌠                                                          ⌠  ⌠
# ⎢ ⎮  ⎮    ⎛           ⎛ 2    ⎞             2        ⎞           ⎮  ⎮
# ⎢ ⎮  ⎮  E⋅⎝x⋅(dx - x)⋅⎝v  - 1⎠ + 2⋅(dy - y) ⋅(v + 1)⎠           ⎮  ⎮  E⋅(dy -
# ⎢ ⎮  ⎮  ───────────────────────────────────────────── dx dy     ⎮  ⎮  ────────
# ⎢ ⎮  ⎮                2   2         ⎛ 2    ⎞                    ⎮  ⎮
# ⎢ ⎮  ⎮            2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                    ⎮  ⎮
# ⎢ ⌡  ⌡                                                          ⌡  ⌡
# ⎢ 0  0                                                          0  0
# ⎢
# ⎢dy dx                                                         dy dx
# ⎢⌠  ⌠                                                          ⌠  ⌠
# ⎢⎮  ⎮              ⎛                         ⎛ 2    ⎞⎞         ⎮  ⎮    ⎛
# ⎢⎮  ⎮  -E⋅(dy - y)⋅⎝2⋅v⋅x⋅(v + 1) + (dx - x)⋅⎝v  - 1⎠⎠         ⎮  ⎮  E⋅⎝-2⋅x⋅(
# ⎢⎮  ⎮  ──────────────────────────────────────────────── dx dy  ⎮  ⎮  ─────────
# ⎢⎮  ⎮                 2   2         ⎛ 2    ⎞                   ⎮  ⎮
# ⎢⎮  ⎮             2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                   ⎮  ⎮
# ⎢⌡  ⌡                                                          ⌡  ⌡
# ⎣0  0                                                          0  0
#
#                                                dy dx
#                                                ⌠  ⌠
#                                                ⎮  ⎮    ⎛
# E⋅(dx⋅dy - dx⋅y - dy⋅x + x⋅y)                  ⎮  ⎮  E⋅⎝-2⋅y⋅(dy - y)⋅(v + 1)
# ────────────────────────────── dx dy           ⎮  ⎮  ─────────────────────────
#           2   2                                ⎮  ⎮                 2   2
#       2⋅dx ⋅dy ⋅(v - 1)                        ⎮  ⎮             2⋅dx ⋅dy ⋅(v +
#                                                ⌡  ⌡
#                                                0  0
#
#                                                dy dx
#                                                ⌠  ⌠
#        2                   2 ⎛ 2    ⎞⎞         ⎮  ⎮              ⎛
# dx - x) ⋅(v + 1) + (dy - y) ⋅⎝v  - 1⎠⎠         ⎮  ⎮  -E⋅(dx - x)⋅⎝2⋅v⋅y⋅(v + 1
# ────────────────────────────────────── dx dy   ⎮  ⎮  ─────────────────────────
#       2   2         ⎛ 2    ⎞                   ⎮  ⎮                 2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                   ⎮  ⎮             2⋅dx ⋅dy ⋅(v +
#                                                ⌡  ⌡
#                                                0  0
#
#                                                     dy dx
#                                                     ⌠  ⌠
#    ⎛                         ⎛ 2    ⎞⎞              ⎮  ⎮    ⎛     2
# x)⋅⎝2⋅v⋅y⋅(v + 1) + (dy - y)⋅⎝v  - 1⎠⎠              ⎮  ⎮  E⋅⎝- 2⋅y ⋅(v + 1) +
# ─────────────────────────────────────── dx dy       ⎮  ⎮  ────────────────────
#       2   2         ⎛ 2    ⎞                        ⎮  ⎮             2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                        ⎮  ⎮         2⋅dx ⋅dy ⋅(v
#                                                     ⌡  ⌡
#                                                     0  0
#
#
#                                                                dy dx
#       ⎛ 2    ⎞             2        ⎞                          ⌠  ⌠
#  - y)⋅⎝v  - 1⎠ + 2⋅(dx - x) ⋅(v + 1)⎠                          ⎮  ⎮     E⋅y⋅(d
# ───────────────────────────────────── dx dy                    ⎮  ⎮  ─────────
#       2   2         ⎛ 2    ⎞                                   ⎮  ⎮      2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                                   ⎮  ⎮  2⋅dx ⋅dy
#                                                                ⌡  ⌡
#                                                                0  0
#
#                                                     dy dx
#                                                     ⌠  ⌠
#                               ⎛ 2    ⎞⎞             ⎮  ⎮    ⎛           ⎛ 2
# (dx - x)⋅(v + 1) - x⋅(dy - y)⋅⎝v  - 1⎠⎠             ⎮  ⎮  E⋅⎝x⋅(dx - x)⋅⎝v  -
# ─────────────────────────────────────── dx dy       ⎮  ⎮  ────────────────────
#       2   2         ⎛ 2    ⎞                        ⎮  ⎮            2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                        ⎮  ⎮        2⋅dx ⋅dy ⋅(v +
#                                                     ⌡  ⌡
#                                                     0  0
#
#
#                                                            dy dx
#                              ⎛ 2    ⎞⎞                     ⌠  ⌠
# dx - x)⋅(v + 1) - y⋅(dy - y)⋅⎝v  - 1⎠⎠                     ⎮  ⎮  E⋅y⋅(dx⋅v - d
# ────────────────────────────────────── dx dy               ⎮  ⎮  ─────────────
#       2   2         ⎛ 2    ⎞                               ⎮  ⎮          2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                               ⎮  ⎮      2⋅dx ⋅dy
#                                                            ⌡  ⌡
#                                                            0  0
#
#                                                dy dx
#                                                ⌠  ⌠
#    ⎛                         ⎛ 2    ⎞⎞         ⎮  ⎮    ⎛             ⎛ 2    ⎞
# y)⋅⎝2⋅v⋅(dx - x)⋅(v + 1) + x⋅⎝v  - 1⎠⎠         ⎮  ⎮  E⋅⎝- x⋅(dx - x)⋅⎝v  - 1⎠
# ────────────────────────────────────── dx dy   ⎮  ⎮  ─────────────────────────
#       2   2         ⎛ 2    ⎞                   ⎮  ⎮                 2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                   ⎮  ⎮             2⋅dx ⋅dy ⋅(v +
#                                                ⌡  ⌡
#                                                0  0
#
#                                                dy dx
#                                                ⌠  ⌠
#                           2 ⎛   2    ⎞⎞        ⎮  ⎮    ⎛
# dx - x)⋅(v + 1) + (dy - y) ⋅⎝- v  + 1⎠⎠        ⎮  ⎮  E⋅⎝-2⋅v⋅x⋅y⋅(v + 1) + (dx
# ─────────────────────────────────────── dx dy  ⎮  ⎮  ─────────────────────────
#       2   2         ⎛ 2    ⎞                   ⎮  ⎮                  2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                   ⎮  ⎮              2⋅dx ⋅dy ⋅(v
#                                                ⌡  ⌡
#                                                0  0
#
#                                  dy dx
#                                  ⌠  ⌠
#           2 ⎛   2    ⎞⎞          ⎮  ⎮             ⎛                         ⎛
# + (dx - x) ⋅⎝- v  + 1⎠⎠          ⎮  ⎮  E⋅(dx - x)⋅⎝2⋅v⋅(dy - y)⋅(v + 1) + y⋅⎝v
# ─────────────────────── dx dy    ⎮  ⎮  ───────────────────────────────────────
#     ⎛ 2    ⎞                     ⎮  ⎮                2   2         ⎛ 2    ⎞
#  1)⋅⎝v  - 1⎠                     ⎮  ⎮            2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#                                  ⌡  ⌡
#                                  0  0
#
#                                   dy dx
#                                   ⌠  ⌠
#              ⎛ 2    ⎞⎞            ⎮  ⎮    ⎛           ⎛ 2    ⎞             2
# ) + (dy - y)⋅⎝v  - 1⎠⎠            ⎮  ⎮  E⋅⎝y⋅(dy - y)⋅⎝v  - 1⎠ + 2⋅(dx - x) ⋅(
# ─────────────────────── dx dy     ⎮  ⎮  ──────────────────────────────────────
#     ⎛ 2    ⎞                      ⎮  ⎮                2   2         ⎛ 2    ⎞
#  1)⋅⎝v  - 1⎠                      ⎮  ⎮            2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#                                   ⌡  ⌡
#                                   0  0
#
#
#                                                 dy dx
#         2 ⎛ 2    ⎞⎞                             ⌠  ⌠
# (dx - x) ⋅⎝v  - 1⎠⎠                             ⎮  ⎮     E⋅y⋅(dx - x)
# ─────────────────── dx dy                       ⎮  ⎮  ───────────────── dx dy
#      ⎛ 2    ⎞                                   ⎮  ⎮      2   2
# + 1)⋅⎝v  - 1⎠                                   ⎮  ⎮  2⋅dx ⋅dy ⋅(v - 1)
#                                                 ⌡  ⌡
#                                                 0  0
#
#                                       dy dx
#                                       ⌠  ⌠
#                                       ⎮  ⎮    ⎛ 2 ⎛ 2    ⎞             2
# x - x)                                ⎮  ⎮  E⋅⎝y ⋅⎝v  - 1⎠ - 2⋅(dx - x) ⋅(v +
# ──────── dx dy                        ⎮  ⎮  ──────────────────────────────────
#                                       ⎮  ⎮            2   2         ⎛ 2    ⎞
# ⋅(v - 1)                              ⎮  ⎮        2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#                                       ⌡  ⌡
#                                       0  0
#
#
#                                              dy dx
#  ⎞      2        ⎞                           ⌠  ⌠
# 1⎠ + 2⋅y ⋅(v + 1)⎠                           ⎮  ⎮  E⋅y⋅(-2⋅dx⋅v + v⋅x + x)
# ────────────────── dx dy                     ⎮  ⎮  ─────────────────────── dx
#     ⎛ 2    ⎞                                 ⎮  ⎮         2   2 ⎛ 2    ⎞
#  1)⋅⎝v  - 1⎠                                 ⎮  ⎮     2⋅dx ⋅dy ⋅⎝v  - 1⎠
#                                              ⌡  ⌡
#                                              0  0
#
#                                          dy dx
#                                          ⌠  ⌠
#                                          ⎮  ⎮    ⎛             2      2    2⎞
# x + v⋅x + x)                             ⎮  ⎮  E⋅⎝-2⋅dx⋅x - v⋅y  + 2⋅x  + y ⎠
# ──────────── dx dy                       ⎮  ⎮  ──────────────────────────────
#  ⎛ 2    ⎞                                ⎮  ⎮            2   2 ⎛ 2    ⎞
# ⋅⎝v  - 1⎠                                ⎮  ⎮        2⋅dx ⋅dy ⋅⎝v  - 1⎠
#                                          ⌡  ⌡
#                                          0  0
#
#                                 dy dx
#                                 ⌠  ⌠
#                       ⎞         ⎮  ⎮    ⎛
# + 2⋅y⋅(dy - y)⋅(v + 1)⎠         ⎮  ⎮  E⋅⎝-2⋅v⋅(dx - x)⋅(dy - y)⋅(v + 1) + x⋅y⋅
# ─────────────────────── dx dy   ⎮  ⎮  ────────────────────────────────────────
#     ⎛ 2    ⎞                    ⎮  ⎮                  2   2         ⎛ 2    ⎞
#  1)⋅⎝v  - 1⎠                    ⎮  ⎮              2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#                                 ⌡  ⌡
#                                 0  0
#
#                                  dy dx
#                                  ⌠  ⌠
#                ⎛ 2    ⎞⎞         ⎮  ⎮    ⎛                                  ⎛
#  - x)⋅(dy - y)⋅⎝v  - 1⎠⎠         ⎮  ⎮  E⋅⎝2⋅x⋅(dx - x)⋅(v + 1) - y⋅(dy - y)⋅⎝v
# ──────────────────────── dx dy   ⎮  ⎮  ───────────────────────────────────────
#      ⎛ 2    ⎞                    ⎮  ⎮                2   2         ⎛ 2    ⎞
# + 1)⋅⎝v  - 1⎠                    ⎮  ⎮            2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#                                  ⌡  ⌡
#                                  0  0
#
#                  dy dx
#                  ⌠  ⌠
# 2    ⎞⎞          ⎮  ⎮    ⎛             ⎛ 2    ⎞                       ⎞
#   - 1⎠⎠          ⎮  ⎮  E⋅⎝- x⋅(dx - x)⋅⎝v  - 1⎠ + 2⋅y⋅(dy - y)⋅(v + 1)⎠
# ─────── dx dy    ⎮  ⎮  ──────────────────────────────────────────────── dx dy
#                  ⎮  ⎮                 2   2         ⎛ 2    ⎞
#                  ⎮  ⎮             2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#                  ⌡  ⌡
#                  0  0
#
#                  dy dx
#                  ⌠  ⌠
#       ⎞          ⎮  ⎮    ⎛                                    ⎛ 2    ⎞⎞
# v + 1)⎠          ⎮  ⎮  E⋅⎝2⋅v⋅y⋅(dx - x)⋅(v + 1) - x⋅(dy - y)⋅⎝v  - 1⎠⎠
# ─────── dx dy    ⎮  ⎮  ──────────────────────────────────────────────── dx dy
#                  ⎮  ⎮                 2   2         ⎛ 2    ⎞
#                  ⎮  ⎮             2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#                  ⌡  ⌡
#                  0  0
#
#                       dy dx
#                       ⌠  ⌠
#                       ⎮  ⎮    ⎛           ⎛ 2    ⎞      2        ⎞
#                       ⎮  ⎮  E⋅⎝x⋅(dx - x)⋅⎝v  - 1⎠ + 2⋅y ⋅(v + 1)⎠
#                       ⎮  ⎮  ────────────────────────────────────── dx dy
#                       ⎮  ⎮            2   2         ⎛ 2    ⎞
#                       ⎮  ⎮        2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#                       ⌡  ⌡
#                       0  0
#
#
#                              dy dx
#   ⎞                          ⌠  ⌠
# 1)⎠                          ⎮  ⎮  E⋅y⋅(-2⋅dx⋅v + v⋅x + x)
# ─── dx dy                    ⎮  ⎮  ─────────────────────── dx dy
#                              ⎮  ⎮         2   2 ⎛ 2    ⎞
#                              ⎮  ⎮     2⋅dx ⋅dy ⋅⎝v  - 1⎠
#                              ⌡  ⌡
#                              0  0
#
#                                dy dx
#                                ⌠  ⌠
#                                ⎮  ⎮    ⎛   2    2      2⎞
#                                ⎮  ⎮  E⋅⎝v⋅x  - x  - 2⋅y ⎠
# dy                             ⎮  ⎮  ──────────────────── dx dy
#                                ⎮  ⎮       2   2 ⎛ 2    ⎞
#                                ⎮  ⎮   2⋅dx ⋅dy ⋅⎝v  - 1⎠
#                                ⌡  ⌡
#                                0  0
#
#
#                                 dy dx
#                                 ⌠  ⌠
#                                 ⎮  ⎮       -E⋅x⋅y
# dx dy                           ⎮  ⎮  ───────────────── dx dy
#                                 ⎮  ⎮      2   2
#                                 ⎮  ⎮  2⋅dx ⋅dy ⋅(v - 1)
#                                 ⌡  ⌡
#                                 0  0
#
#                          dy dx
#                          ⌠  ⌠
# ⎛ 2    ⎞⎞                ⎮  ⎮     ⎛            2    2      2⎞
# ⎝v  - 1⎠⎠                ⎮  ⎮  -E⋅⎝2⋅dy⋅y + v⋅x  - x  - 2⋅y ⎠
# ───────── dx dy          ⎮  ⎮  ─────────────────────────────── dx dy
#                          ⎮  ⎮             2   2 ⎛ 2    ⎞
#                          ⎮  ⎮         2⋅dx ⋅dy ⋅⎝v  - 1⎠
#                          ⌡  ⌡
#                          0  0
#
#
#                             dy dx
# 2    ⎞⎞                     ⌠  ⌠
#   - 1⎠⎠                     ⎮  ⎮  E⋅x⋅(dy⋅v - dy + v⋅y + y)
# ─────── dx dy               ⎮  ⎮  ───────────────────────── dx dy
#                             ⎮  ⎮          2   2 ⎛ 2    ⎞
#                             ⎮  ⎮      2⋅dx ⋅dy ⋅⎝v  - 1⎠
#                             ⌡  ⌡
#                             0  0
#
#  dy dx                                                           dy dx
#  ⌠  ⌠                                                            ⌠  ⌠
#  ⎮  ⎮    ⎛                                    ⎛ 2    ⎞⎞          ⎮  ⎮    ⎛
#  ⎮  ⎮  E⋅⎝2⋅v⋅x⋅(dy - y)⋅(v + 1) - y⋅(dx - x)⋅⎝v  - 1⎠⎠          ⎮  ⎮  E⋅⎝x⋅(d
#  ⎮  ⎮  ──────────────────────────────────────────────── dx dy    ⎮  ⎮  ───────
#  ⎮  ⎮                 2   2         ⎛ 2    ⎞                     ⎮  ⎮
#  ⎮  ⎮             2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                     ⎮  ⎮
#  ⌡  ⌡                                                            ⌡  ⌡
#  0  0                                                            0  0
#
#   dy dx                                                         dy dx
#   ⌠  ⌠                                                          ⌠  ⌠
#   ⎮  ⎮    ⎛                                  ⎛ 2    ⎞⎞          ⎮  ⎮
#   ⎮  ⎮  E⋅⎝2⋅x⋅(dx - x)⋅(v + 1) - y⋅(dy - y)⋅⎝v  - 1⎠⎠          ⎮  ⎮  E⋅(dy -
#   ⎮  ⎮  ────────────────────────────────────────────── dx dy    ⎮  ⎮  ────────
#   ⎮  ⎮                2   2         ⎛ 2    ⎞                    ⎮  ⎮
#   ⎮  ⎮            2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                    ⎮  ⎮
#   ⌡  ⌡                                                          ⌡  ⌡
#   0  0                                                          0  0
#
#                                                                dy dx
#             dy dx                                              ⌠  ⌠
#             ⌠  ⌠                                               ⎮  ⎮    ⎛
#             ⎮  ⎮  E⋅y⋅(dx⋅v - dx + v⋅x + x)                    ⎮  ⎮  E⋅⎝- x⋅(d
#             ⎮  ⎮  ───────────────────────── dx dy              ⎮  ⎮  ─────────
#             ⎮  ⎮          2   2 ⎛ 2    ⎞                       ⎮  ⎮
#             ⎮  ⎮      2⋅dx ⋅dy ⋅⎝v  - 1⎠                       ⎮  ⎮
#             ⌡  ⌡                                               ⌡  ⌡
#             0  0                                               0  0
#
#           dy dx                                                dy dx
#           ⌠  ⌠                                                 ⌠  ⌠
#           ⎮  ⎮    ⎛             2      2    2⎞                 ⎮  ⎮    ⎛
#           ⎮  ⎮  E⋅⎝-2⋅dx⋅x - v⋅y  + 2⋅x  + y ⎠                 ⎮  ⎮  E⋅⎝-2⋅v⋅(
#           ⎮  ⎮  ────────────────────────────── dx dy           ⎮  ⎮  ─────────
#           ⎮  ⎮            2   2 ⎛ 2    ⎞                       ⎮  ⎮
#           ⎮  ⎮        2⋅dx ⋅dy ⋅⎝v  - 1⎠                       ⎮  ⎮
#           ⌡  ⌡                                                 ⌡  ⌡
#           0  0                                                 0  0
#
#                                                                         dy dx
#                 dy dx                                                   ⌠  ⌠
#                 ⌠  ⌠                                                    ⎮  ⎮
#                 ⎮  ⎮       -E⋅x⋅y                                       ⎮  ⎮
#                 ⎮  ⎮  ───────────────── dx dy                           ⎮  ⎮
#                 ⎮  ⎮      2   2                                         ⎮  ⎮
#                 ⎮  ⎮  2⋅dx ⋅dy ⋅(v - 1)                                 ⎮  ⎮
#                 ⌡  ⌡                                                    ⌡  ⌡
#                 0  0                                                    0  0
#
#              dy dx
#              ⌠  ⌠                                                           dy
#              ⎮  ⎮     ⎛     2      2    2⎞                                  ⌠
#              ⎮  ⎮  -E⋅⎝- v⋅y  + 2⋅x  + y ⎠                                  ⎮
#              ⎮  ⎮  ──────────────────────── dx dy                           ⎮
#              ⎮  ⎮         2   2 ⎛ 2    ⎞                                    ⎮
#              ⎮  ⎮     2⋅dx ⋅dy ⋅⎝v  - 1⎠                                    ⎮
#              ⌡  ⌡                                                           ⌡
#              0  0                                                           0
#
#                                                                      dy dx
#              dy dx                                                   ⌠  ⌠
#              ⌠  ⌠                                                    ⎮  ⎮    ⎛
#              ⎮  ⎮  E⋅x⋅(-2⋅dy⋅v + v⋅y + y)                           ⎮  ⎮  E⋅⎝
#              ⎮  ⎮  ─────────────────────── dx dy                     ⎮  ⎮  ───
#              ⎮  ⎮         2   2 ⎛ 2    ⎞                             ⎮  ⎮
#              ⎮  ⎮     2⋅dx ⋅dy ⋅⎝v  - 1⎠                             ⎮  ⎮
#              ⌡  ⌡                                                    ⌡  ⌡
#              0  0                                                    0  0
#
#       dy dx
#       ⌠  ⌠
#       ⎮  ⎮    ⎛   2                      ⎛ 2    ⎞⎞
#       ⎮  ⎮  E⋅⎝2⋅x ⋅(v + 1) + y⋅(dy - y)⋅⎝v  - 1⎠⎠
#       ⎮  ⎮  ────────────────────────────────────── dx dy
#       ⎮  ⎮            2   2         ⎛ 2    ⎞
#       ⎮  ⎮        2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠
#       ⌡  ⌡
#       0  0
#
#                                                 dy dx
#                                                 ⌠  ⌠
#        ⎛ 2    ⎞             2        ⎞          ⎮  ⎮              ⎛
# x - x)⋅⎝v  - 1⎠ + 2⋅(dy - y) ⋅(v + 1)⎠          ⎮  ⎮  -E⋅(dy - y)⋅⎝2⋅v⋅x⋅(v +
# ────────────────────────────────────── dx dy    ⎮  ⎮  ────────────────────────
#        2   2         ⎛ 2    ⎞                   ⎮  ⎮                 2   2
#    2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                   ⎮  ⎮             2⋅dx ⋅dy ⋅(v
#                                                 ⌡  ⌡
#                                                 0  0
#
#                                                 dy dx
#                                                 ⌠  ⌠
#    ⎛                         ⎛ 2    ⎞⎞          ⎮  ⎮    ⎛
# y)⋅⎝2⋅v⋅(dx - x)⋅(v + 1) + x⋅⎝v  - 1⎠⎠          ⎮  ⎮  E⋅⎝-2⋅x⋅(dx - x)⋅(v + 1)
# ────────────────────────────────────── dx dy    ⎮  ⎮  ────────────────────────
#       2   2         ⎛ 2    ⎞                    ⎮  ⎮                 2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                    ⎮  ⎮             2⋅dx ⋅dy ⋅(v
#                                                 ⌡  ⌡
#                                                 0  0
#
#                                                 dy dx
#                                                 ⌠  ⌠
#        ⎛ 2    ⎞                       ⎞         ⎮  ⎮    ⎛
# x - x)⋅⎝v  - 1⎠ + 2⋅y⋅(dy - y)⋅(v + 1)⎠         ⎮  ⎮  E⋅⎝-2⋅v⋅x⋅y⋅(v + 1) + (d
# ─────────────────────────────────────── dx dy   ⎮  ⎮  ────────────────────────
#       2   2         ⎛ 2    ⎞                    ⎮  ⎮                  2   2
#   2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                    ⎮  ⎮              2⋅dx ⋅dy ⋅(v
#                                                 ⌡  ⌡
#                                                 0  0
#
#                                                  dy dx
#                                                  ⌠  ⌠
#                                ⎛ 2    ⎞⎞         ⎮  ⎮    ⎛
# dx - x)⋅(dy - y)⋅(v + 1) + x⋅y⋅⎝v  - 1⎠⎠         ⎮  ⎮  E⋅⎝2⋅x⋅(dx - x)⋅(v + 1)
# ──────────────────────────────────────── dx dy   ⎮  ⎮  ───────────────────────
#        2   2         ⎛ 2    ⎞                    ⎮  ⎮                2   2
#    2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                    ⎮  ⎮            2⋅dx ⋅dy ⋅(v
#                                                  ⌡  ⌡
#                                                  0  0
#
#
#                                                             dy dx
#    ⎛            2    2      2⎞                              ⌠  ⌠
# -E⋅⎝2⋅dy⋅y + v⋅x  - x  - 2⋅y ⎠                              ⎮  ⎮  E⋅x⋅(dy⋅v -
# ─────────────────────────────── dx dy                       ⎮  ⎮  ────────────
#            2   2 ⎛ 2    ⎞                                   ⎮  ⎮          2
#        2⋅dx ⋅dy ⋅⎝v  - 1⎠                                   ⎮  ⎮      2⋅dx ⋅dy
#                                                             ⌡  ⌡
#                                                             0  0
#
#                                                      dy dx
#  dx                                                  ⌠  ⌠
#  ⌠                                                   ⎮  ⎮    ⎛   2
#  ⎮  E⋅x⋅(-2⋅dy⋅v + v⋅y + y)                          ⎮  ⎮  E⋅⎝2⋅x ⋅(v + 1) + y
#  ⎮  ─────────────────────── dx dy                    ⎮  ⎮  ───────────────────
#  ⎮         2   2 ⎛ 2    ⎞                            ⎮  ⎮            2   2
#  ⎮     2⋅dx ⋅dy ⋅⎝v  - 1⎠                            ⎮  ⎮        2⋅dx ⋅dy ⋅(v
#  ⌡                                                   ⌡  ⌡
#  0                                                   0  0
#
#
#                                                                 dy dx
#  2 ⎛ 2    ⎞             2        ⎞                              ⌠  ⌠
# x ⋅⎝v  - 1⎠ - 2⋅(dy - y) ⋅(v + 1)⎠                              ⎮  ⎮     E⋅x⋅(
# ────────────────────────────────── dx dy                        ⎮  ⎮  ────────
#        2   2         ⎛ 2    ⎞                                   ⎮  ⎮      2
#    2⋅dx ⋅dy ⋅(v + 1)⋅⎝v  - 1⎠                                   ⎮  ⎮  2⋅dx ⋅dy
#                                                                 ⌡  ⌡
#                                                                 0  0
#
#                                                      dy dx
#  dy dx                                               ⌠  ⌠
#  ⌠  ⌠                                                ⎮  ⎮    ⎛     2
#  ⎮  ⎮     E⋅x⋅(dy - y)                               ⎮  ⎮  E⋅⎝- 2⋅x ⋅(v + 1) +
#  ⎮  ⎮  ───────────────── dx dy                       ⎮  ⎮  ───────────────────
#  ⎮  ⎮      2   2                                     ⎮  ⎮             2   2
#  ⎮  ⎮  2⋅dx ⋅dy ⋅(v - 1)                             ⎮  ⎮         2⋅dx ⋅dy ⋅(v
#  ⌡  ⌡                                                ⌡  ⌡
#  0  0                                                0  0
#
#                                ⎤
#                                ⎥
#               ⎛ 2    ⎞⎞        ⎥
# 1) + (dx - x)⋅⎝v  - 1⎠⎠        ⎥
# ──────────────────────── dx dy ⎥
#      ⎛ 2    ⎞                  ⎥
# + 1)⋅⎝v  - 1⎠                  ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#            2 ⎛   2    ⎞⎞       ⎥
#  + (dy - y) ⋅⎝- v  + 1⎠⎠       ⎥
# ──────────────────────── dx dy ⎥
#      ⎛ 2    ⎞                  ⎥
# + 1)⋅⎝v  - 1⎠                  ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                 ⎛ 2    ⎞⎞      ⎥
# x - x)⋅(dy - y)⋅⎝v  - 1⎠⎠      ⎥
# ───────────────────────── dx dy⎥
#       ⎛ 2    ⎞                 ⎥
#  + 1)⋅⎝v  - 1⎠                 ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#               ⎛ 2    ⎞⎞        ⎥
#  - y⋅(dy - y)⋅⎝v  - 1⎠⎠        ⎥
# ─────────────────────── dx dy  ⎥
#      ⎛ 2    ⎞                  ⎥
# + 1)⋅⎝v  - 1⎠                  ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
# dy + v⋅y + y)                  ⎥
# ───────────── dx dy            ⎥
# 2 ⎛ 2    ⎞                     ⎥
#  ⋅⎝v  - 1⎠                     ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#           ⎛ 2    ⎞⎞            ⎥
# ⋅(dy - y)⋅⎝v  - 1⎠⎠            ⎥
# ─────────────────── dx dy      ⎥
#      ⎛ 2    ⎞                  ⎥
# + 1)⋅⎝v  - 1⎠                  ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
# dy - y)                        ⎥
# ───────── dx dy                ⎥
# 2                              ⎥
#  ⋅(v - 1)                      ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#          2 ⎛ 2    ⎞⎞           ⎥
#  (dy - y) ⋅⎝v  - 1⎠⎠           ⎥
# ──────────────────── dx dy     ⎥
#       ⎛ 2    ⎞                 ⎥
#  + 1)⋅⎝v  - 1⎠                 ⎥
#                                ⎥
#                                ⎦

# %%
M = evaluate(M)
M
# Out:
# ⎡ 0.488888888888889    0.166666666666667   0.0444444444444445   0.033333333333
# ⎢
# ⎢ 0.166666666666667    0.488888888888889   -0.0333333333333334  -0.28888888888
# ⎢
# ⎢0.0444444444444445   -0.0333333333333334   0.488888888888889   -0.16666666666
# ⎢
# ⎢0.0333333333333333   -0.288888888888889   -0.166666666666667    0.48888888888
# ⎢
# ⎢-0.244444444444444   -0.166666666666667   -0.288888888888889   -0.03333333333
# ⎢
# ⎢-0.166666666666667   -0.244444444444444   0.0333333333333333   0.044444444444
# ⎢
# ⎢-0.288888888888889   0.0333333333333333   -0.244444444444444    0.16666666666
# ⎢
# ⎣-0.0333333333333333  0.0444444444444444    0.166666666666667   -0.24444444444
#
# 3333   -0.244444444444444   -0.166666666666667   -0.288888888888889   -0.03333
#
# 8889   -0.166666666666667   -0.244444444444444   0.0333333333333333   0.044444
#
# 6667   -0.288888888888889   0.0333333333333333   -0.244444444444444    0.16666
#
# 8889   -0.0333333333333333  0.0444444444444445    0.166666666666667   -0.24444
#
# 33333   0.488888888888889    0.166666666666667   0.0444444444444445   0.033333
#
# 4445    0.166666666666667    0.488888888888889   -0.0333333333333333  -0.28888
#
# 6667   0.0444444444444445   -0.0333333333333333   0.488888888888889   -0.16666
#
# 4444   0.0333333333333334   -0.288888888888889   -0.166666666666667    0.48888
#
# 33333333333⎤
#            ⎥
# 4444444444 ⎥
#            ⎥
# 6666666667 ⎥
#            ⎥
# 4444444444 ⎥
#            ⎥
# 3333333334 ⎥
#            ⎥
# 8888888889 ⎥
#            ⎥
# 6666666667 ⎥
#            ⎥
# 8888888889 ⎦

# %%
from Element import *

elem = Quadrilateral(0, E=E_value, v=v_value, elasticidade=True, ndim=2)

elem.AddNode(Node(0, 0.0, 0.0))
elem.AddNode(Node(1, 0.0, dy_value))
elem.AddNode(Node(2, dx_value, dy_value))
elem.AddNode(Node(3, dx_value, 0.0))


print elem.CalcKlocal()
# Out:
# [[ 0.48888889  0.16666667  0.04444444  0.03333333 -0.24444444 -0.16666667
#   -0.28888889 -0.03333333]
#  [ 0.16666667  0.48888889 -0.03333333 -0.28888889 -0.16666667 -0.24444444
#    0.03333333  0.04444444]
#  [ 0.04444444 -0.03333333  0.48888889 -0.16666667 -0.28888889  0.03333333
#   -0.24444444  0.16666667]
#  [ 0.03333333 -0.28888889 -0.16666667  0.48888889 -0.03333333  0.04444444
#    0.16666667 -0.24444444]
#  [-0.24444444 -0.16666667 -0.28888889 -0.03333333  0.48888889  0.16666667
#    0.04444444  0.03333333]
#  [-0.16666667 -0.24444444  0.03333333  0.04444444  0.16666667  0.48888889
#   -0.03333333 -0.28888889]
#  [-0.28888889  0.03333333 -0.24444444  0.16666667  0.04444444 -0.03333333
#    0.48888889 -0.16666667]
#  [-0.03333333  0.04444444  0.16666667 -0.24444444  0.03333333 -0.28888889
#   -0.16666667  0.48888889]]

# %%
np.linalg.norm(elem.CalcKlocal() - convert_to_np(M))
# Out:
# 5.45133919711e-16

# %%
np.linalg.norm(elem.Hooke() - convert_to_np(D.doit().subs(E, E_value).subs(v, v_value)))
# Out:
# 0.0

# %% [markdown]
# # Construindo solucao analitica

# %%
def applyS(N):

    xddx = diff(N[0,0], x)
    yddy = diff(N[1,0], y)
    
    xddy = diff(N[0,0], y)
    yddx = diff(N[1,0], x)
    
    return Matrix([[xddx], [yddy],  [xddy + yddx]])
    
def applySt(N):
    a1 = diff(N[0,0], x) + diff(N[2,0], y)
    a2 = diff(N[1,0], y) + diff(N[2,0], x)
    
    return Matrix([[a1],[a2]])

# %%
u = Matrix([[sin(pi*x)*sin(pi*y)],[0]])

applyS(u)
# Out:
# ⎡π⋅sin(π⋅y)⋅cos(π⋅x)⎤
# ⎢                   ⎥
# ⎢         0         ⎥
# ⎢                   ⎥
# ⎣π⋅sin(π⋅x)⋅cos(π⋅y)⎦

# %%
k = D*applyS(u)
k
# Out:
# ⎡ -π⋅E⋅sin(π⋅y)⋅cos(π⋅x)  ⎤
# ⎢ ─────────────────────── ⎥
# ⎢           2             ⎥
# ⎢          v  - 1         ⎥
# ⎢                         ⎥
# ⎢-π⋅E⋅v⋅sin(π⋅y)⋅cos(π⋅x) ⎥
# ⎢─────────────────────────⎥
# ⎢           2             ⎥
# ⎢          v  - 1         ⎥
# ⎢                         ⎥
# ⎢  π⋅E⋅sin(π⋅x)⋅cos(π⋅y)  ⎥
# ⎢  ─────────────────────  ⎥
# ⎣        2⋅(v + 1)        ⎦

# %%
applySt(k)
# Out:
# ⎡   2                        2                      ⎤
# ⎢  π ⋅E⋅sin(π⋅x)⋅sin(π⋅y)   π ⋅E⋅sin(π⋅x)⋅sin(π⋅y)  ⎥
# ⎢  ────────────────────── - ──────────────────────  ⎥
# ⎢           2                     2⋅(v + 1)         ⎥
# ⎢          v  - 1                                   ⎥
# ⎢                                                   ⎥
# ⎢   2                          2                    ⎥
# ⎢  π ⋅E⋅v⋅cos(π⋅x)⋅cos(π⋅y)   π ⋅E⋅cos(π⋅x)⋅cos(π⋅y)⎥
# ⎢- ──────────────────────── + ──────────────────────⎥
# ⎢            2                      2⋅(v + 1)       ⎥
# ⎣           v  - 1                                  ⎦
